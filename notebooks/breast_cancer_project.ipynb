# %% [markdown]
# # Breast Cancer Classification
# This notebook demonstrates the `breast_cancer_classification` utility.

# %%
from statistics_lessons.projects import breast_cancer_classification

results = breast_cancer_classification()
results
